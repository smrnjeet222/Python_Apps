# %%
import folium

map = folium.Map(location=[27.1751,78.0421],tiles='Stamen Terrain',zoom_start=10)

map

# %%
folium.Marker(location = [27.1751,78.0421] , popup= "TAJ MAHAL",
              icon=folium.Icon(color='red', icon='info-sign')).add_to(map)
map

# %%
folium.Circle(location = [27.1751,78.0421] , radius = 5000 ,
                popup='Agra', color='#3186cc', fill=True, fill_color='#3186cc').add_to(map)
map
